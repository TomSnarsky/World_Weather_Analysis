# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head()
# Out:
#    City_ID        City Country  Max Temp Current Description      Lat  \
# 0        7      Uribia      CO     79.92     overcast clouds  11.7139
# 1       10      Atuona      PF     79.88          few clouds  -9.8000
# 2       22     Rikitea      PF     77.76     overcast clouds -23.1203
# 3       26  La Belgica      BO     75.49    scattered clouds -17.5500
# 4       28       Adrar      MR     70.72           clear sky  20.5022
#
#         Lng                Hotel Name
# 0  -72.2660              Hotel Uribia
# 1 -139.0333               Villa Enata
# 2 -134.9692           People ThankYou
# 3  -63.2167  Colpa Caranda Eco Resort
# 4  -10.0711                       NaN

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
vacation_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=vacation_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Celestun"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Celestun"]
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Panaba"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Tizimin"]
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Cozumel"]

# %%
startarray = vacation_start.to_numpy()
startarray
# Out:
# array([[471, 'Celestun', 'MX', 78.53, 'broken clouds', 20.8667, -90.4,
#         'Posada Lilia']], dtype=object)

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
startarray = vacation_start.to_numpy()
endarray = vacation_end.to_numpy()
stop1array = vacation_stop1.to_numpy()
stop2array = vacation_stop2.to_numpy()
stop3array = vacation_stop3.to_numpy()

start = (startarray[0][5], startarray[0][6])
end = (endarray[0][5], endarray[0][6])
stop1 = (stop1array[0][5], stop1array[0][6])
stop2 = (stop2array[0][5], stop2array[0][6])
stop3 = (stop3array[0][5], stop3array[0][6])

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".

import gmaps
import gmaps.datasets
gmaps.configure(api_key=g_key)

fig = gmaps.figure()
full_trip = gmaps.directions_layer(start, end, waypoints=[stop1, stop2, stop3],
        travel_mode='DRIVING')
fig.add_layer(full_trip)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_start, vacation_stop1, vacation_stop2, vacation_stop3],ignore_index=True)
itinerary_df
# Out:
#    City_ID      City Country  Max Temp Current Description      Lat      Lng  \
# 0      471  Celestun      MX     78.53       broken clouds  20.8667 -90.4000
# 1      615    Panaba      MX     79.48     overcast clouds  21.2833 -88.2667
# 2      150   Tizimin      MX     79.61     overcast clouds  21.1500 -88.1500
# 3      433   Cozumel      MX     78.01    scattered clouds  20.5083 -86.9458
#
#                              Hotel Name
# 0                          Posada Lilia
# 1                      Hotel California
# 2                           silva hogar
# 3  Cozumel Palace® All Inclusive Resort

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel Name}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
itinerary_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
marker_layer = gmaps.marker_layer(locations, info_box_content=itinerary_info)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
