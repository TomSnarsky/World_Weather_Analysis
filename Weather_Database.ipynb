# %%
# Import the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Import the API key
from config import weather_api_key

# %%
# Import the requests library
import requests

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []

# Identify the nearest city for each latitude and longitude combination
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 737

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data
city_data = []

# Print the beginning of the logging
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in the list
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hobart
# Processing Record 2 of Set 1 | ponta do sol
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | jurmala
# Processing Record 5 of Set 1 | rincon
# Processing Record 6 of Set 1 | terrace bay
# Processing Record 7 of Set 1 | sitka
# Processing Record 8 of Set 1 | uribia
# Processing Record 9 of Set 1 | baykit
# Processing Record 10 of Set 1 | tiksi
# Processing Record 11 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | punta arenas
# Processing Record 14 of Set 1 | busselton
# Processing Record 15 of Set 1 | coquimbo
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | ribeira brava
# Processing Record 19 of Set 1 | norman wells
# Processing Record 20 of Set 1 | luderitz
# Processing Record 21 of Set 1 | astoria
# Processing Record 22 of Set 1 | pangai
# Processing Record 23 of Set 1 | viedma
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | kapaa
# Processing Record 28 of Set 1 | la belgica
# Processing Record 29 of Set 1 | qeshm
# Processing Record 30 of Set 1 | adrar
# Processing Record 31 of Set 1 | fairbanks
# Processing Record 32 of Set 1 | cidreira
# Processing Record 33 of Set 1 | pisco
# Processing Record 34 of Set 1 | hithadhoo
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | los llanos de aridane
# Processing Record 37 of Set 1 | cabo san lucas
# Processing Record 38 of Set 1 | aguas vermelhas
# Processing Record 39 of Set 1 | sur
# Processing Record 40 of Set 1 | nichinan
# Processing Record 41 of Set 1 | avarua
# Processing Record 42 of Set 1 | sorochinsk
# Processing Record 43 of Set 1 | grindavik
# Processing Record 44 of Set 1 | markova
# Processing Record 45 of Set 1 | albany
# Processing Record 46 of Set 1 | husavik
# Processing Record 47 of Set 1 | yellowknife
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | gamboma
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | tangwani
# Processing Record 2 of Set 2 | zbysov
# Processing Record 3 of Set 2 | new norfolk
# Processing Record 4 of Set 2 | sola
# Processing Record 5 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 6 of Set 2 | vila franca do campo
# Processing Record 7 of Set 2 | tasiilaq
# Processing Record 8 of Set 2 | dikson
# Processing Record 9 of Set 2 | bluff
# Processing Record 10 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 2 | griffith
# Processing Record 12 of Set 2 | vaini
# Processing Record 13 of Set 2 | blind river
# Processing Record 14 of Set 2 | port blair
# Processing Record 15 of Set 2 | cape town
# Processing Record 16 of Set 2 | hilo
# Processing Record 17 of Set 2 | tuktoyaktuk
# Processing Record 18 of Set 2 | bethel
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | andevoranto
# City not found. Skipping...
# Processing Record 23 of Set 2 | bandarbeyla
# Processing Record 24 of Set 2 | dali
# Processing Record 25 of Set 2 | fare
# Processing Record 26 of Set 2 | primero de enero
# Processing Record 27 of Set 2 | balabac
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | sao filipe
# Processing Record 30 of Set 2 | hasaki
# Processing Record 31 of Set 2 | astana
# Processing Record 32 of Set 2 | aksarka
# Processing Record 33 of Set 2 | buala
# Processing Record 34 of Set 2 | aripuana
# Processing Record 35 of Set 2 | haines junction
# Processing Record 36 of Set 2 | ahuimanu
# Processing Record 37 of Set 2 | lyubotyn
# Processing Record 38 of Set 2 | auki
# Processing Record 39 of Set 2 | ayan
# Processing Record 40 of Set 2 | moree
# Processing Record 41 of Set 2 | gorontalo
# Processing Record 42 of Set 2 | hermanus
# Processing Record 43 of Set 2 | port elizabeth
# Processing Record 44 of Set 2 | port lincoln
# Processing Record 45 of Set 2 | amahai
# Processing Record 46 of Set 2 | kodiak
# Processing Record 47 of Set 2 | otradnoye
# Processing Record 48 of Set 2 | tommot
# Processing Record 49 of Set 2 | peterhead
# Processing Record 50 of Set 2 | azare
# Processing Record 1 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 3 | kaitangata
# Processing Record 3 of Set 3 | ibotirama
# Processing Record 4 of Set 3 | puerto ayora
# Processing Record 5 of Set 3 | ketchikan
# Processing Record 6 of Set 3 | havelock
# Processing Record 7 of Set 3 | puerto escondido
# Processing Record 8 of Set 3 | salalah
# Processing Record 9 of Set 3 | port hedland
# Processing Record 10 of Set 3 | oyek
# Processing Record 11 of Set 3 | narsaq
# Processing Record 12 of Set 3 | souillac
# Processing Record 13 of Set 3 | victoria
# Processing Record 14 of Set 3 | puerto vallarta
# Processing Record 15 of Set 3 | marsabit
# Processing Record 16 of Set 3 | dunedin
# Processing Record 17 of Set 3 | torbay
# Processing Record 18 of Set 3 | makaha
# Processing Record 19 of Set 3 | jijiga
# Processing Record 20 of Set 3 | oktyabrskiy
# Processing Record 21 of Set 3 | georgetown
# Processing Record 22 of Set 3 | iqaluit
# Processing Record 23 of Set 3 | buta
# Processing Record 24 of Set 3 | uspenskoye
# Processing Record 25 of Set 3 | sisimiut
# Processing Record 26 of Set 3 | ahipara
# Processing Record 27 of Set 3 | majdanpek
# Processing Record 28 of Set 3 | sambava
# Processing Record 29 of Set 3 | shahdadkot
# Processing Record 30 of Set 3 | lakes entrance
# Processing Record 31 of Set 3 | yulara
# Processing Record 32 of Set 3 | chapais
# Processing Record 33 of Set 3 | hohhot
# Processing Record 34 of Set 3 | buraydah
# Processing Record 35 of Set 3 | thinadhoo
# Processing Record 36 of Set 3 | palabuhanratu
# City not found. Skipping...
# Processing Record 37 of Set 3 | duz
# City not found. Skipping...
# Processing Record 38 of Set 3 | tahe
# Processing Record 39 of Set 3 | butaritari
# Processing Record 40 of Set 3 | daitari
# Processing Record 41 of Set 3 | bukene
# Processing Record 42 of Set 3 | barrow
# Processing Record 43 of Set 3 | upernavik
# Processing Record 44 of Set 3 | longyearbyen
# Processing Record 45 of Set 3 | castro
# Processing Record 46 of Set 3 | haftoni
# Processing Record 47 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | havre-saint-pierre
# Processing Record 50 of Set 3 | satana
# Processing Record 1 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 4 | thompson
# Processing Record 3 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 4 of Set 4 | salmon arm
# Processing Record 5 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 6 of Set 4 | hay river
# Processing Record 7 of Set 4 | bermeo
# Processing Record 8 of Set 4 | wum
# Processing Record 9 of Set 4 | muli
# Processing Record 10 of Set 4 | mahebourg
# Processing Record 11 of Set 4 | barguzin
# Processing Record 12 of Set 4 | laiagam
# City not found. Skipping...
# Processing Record 13 of Set 4 | taltal
# Processing Record 14 of Set 4 | vanino
# Processing Record 15 of Set 4 | lerwick
# Processing Record 16 of Set 4 | tizimin
# Processing Record 17 of Set 4 | saint-georges
# Processing Record 18 of Set 4 | wana
# Processing Record 19 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 4 | umkomaas
# Processing Record 21 of Set 4 | los alamos
# Processing Record 22 of Set 4 | nakusp
# Processing Record 23 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 24 of Set 4 | batagay-alyta
# Processing Record 25 of Set 4 | tamala
# Processing Record 26 of Set 4 | kalmunai
# Processing Record 27 of Set 4 | coihaique
# Processing Record 28 of Set 4 | atikokan
# Processing Record 29 of Set 4 | srandakan
# Processing Record 30 of Set 4 | talnakh
# Processing Record 31 of Set 4 | hashtrud
# Processing Record 32 of Set 4 | saldanha
# Processing Record 33 of Set 4 | jalu
# Processing Record 34 of Set 4 | bambous virieux
# Processing Record 35 of Set 4 | bud
# Processing Record 36 of Set 4 | hailar
# Processing Record 37 of Set 4 | kavieng
# Processing Record 38 of Set 4 | sao joao da barra
# Processing Record 39 of Set 4 | ilhabela
# Processing Record 40 of Set 4 | mana
# Processing Record 41 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 42 of Set 4 | guaira
# Processing Record 43 of Set 4 | key west
# Processing Record 44 of Set 4 | coruripe
# Processing Record 45 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 46 of Set 4 | chernyshevskiy
# Processing Record 47 of Set 4 | vanavara
# Processing Record 48 of Set 4 | jieshi
# Processing Record 49 of Set 4 | matara
# Processing Record 50 of Set 4 | phangnga
# Processing Record 1 of Set 5 | marawi
# Processing Record 2 of Set 5 | nantucket
# Processing Record 3 of Set 5 | ixtapa
# Processing Record 4 of Set 5 | ribeira grande
# Processing Record 5 of Set 5 | ancud
# Processing Record 6 of Set 5 | dobeln
# Processing Record 7 of Set 5 | windsor
# Processing Record 8 of Set 5 | bima
# Processing Record 9 of Set 5 | chicama
# Processing Record 10 of Set 5 | byron bay
# Processing Record 11 of Set 5 | guerrero negro
# Processing Record 12 of Set 5 | khandyga
# Processing Record 13 of Set 5 | gat
# Processing Record 14 of Set 5 | vitoria
# Processing Record 15 of Set 5 | mathbaria
# Processing Record 16 of Set 5 | klaksvik
# Processing Record 17 of Set 5 | mar del plata
# Processing Record 18 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 5 | kaeo
# Processing Record 20 of Set 5 | rangapara
# Processing Record 21 of Set 5 | porkhov
# Processing Record 22 of Set 5 | walvis bay
# Processing Record 23 of Set 5 | katha
# City not found. Skipping...
# Processing Record 24 of Set 5 | doka
# Processing Record 25 of Set 5 | moerai
# Processing Record 26 of Set 5 | cabra
# Processing Record 27 of Set 5 | samarai
# Processing Record 28 of Set 5 | ballina
# Processing Record 29 of Set 5 | mayahi
# Processing Record 30 of Set 5 | lagoa
# Processing Record 31 of Set 5 | shemonaikha
# Processing Record 32 of Set 5 | kourou
# Processing Record 33 of Set 5 | fortuna
# Processing Record 34 of Set 5 | bathsheba
# Processing Record 35 of Set 5 | cherskiy
# Processing Record 36 of Set 5 | fort morgan
# Processing Record 37 of Set 5 | emirdag
# Processing Record 38 of Set 5 | kudat
# Processing Record 39 of Set 5 | leningradskiy
# Processing Record 40 of Set 5 | grand-santi
# Processing Record 41 of Set 5 | severo-kurilsk
# Processing Record 42 of Set 5 | arraial do cabo
# Processing Record 43 of Set 5 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 5 | lasa
# Processing Record 45 of Set 5 | nueva concepcion
# Processing Record 46 of Set 5 | ndele
# Processing Record 47 of Set 5 | shebunino
# Processing Record 48 of Set 5 | tautira
# Processing Record 49 of Set 5 | asahikawa
# Processing Record 50 of Set 5 | san pedro
# Processing Record 1 of Set 6 | carnarvon
# Processing Record 2 of Set 6 | tuatapere
# Processing Record 3 of Set 6 | buritizeiro
# Processing Record 4 of Set 6 | banda aceh
# Processing Record 5 of Set 6 | codrington
# Processing Record 6 of Set 6 | catamarca
# Processing Record 7 of Set 6 | kawalu
# Processing Record 8 of Set 6 | yei
# Processing Record 9 of Set 6 | riyadh
# Processing Record 10 of Set 6 | fenoarivo atsinanana
# Processing Record 11 of Set 6 | punta de bombon
# Processing Record 12 of Set 6 | tokmak
# Processing Record 13 of Set 6 | andra
# Processing Record 14 of Set 6 | bengkulu
# Processing Record 15 of Set 6 | hokitika
# Processing Record 16 of Set 6 | geraldton
# Processing Record 17 of Set 6 | ajaccio
# Processing Record 18 of Set 6 | kununurra
# Processing Record 19 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 20 of Set 6 | tauranga
# Processing Record 21 of Set 6 | ostrovnoy
# Processing Record 22 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | olafsvik
# Processing Record 24 of Set 6 | sandi
# Processing Record 25 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 26 of Set 6 | shimoda
# Processing Record 27 of Set 6 | pacific grove
# Processing Record 28 of Set 6 | utrecht
# Processing Record 29 of Set 6 | klang
# Processing Record 30 of Set 6 | vilela
# Processing Record 31 of Set 6 | santa rosa
# Processing Record 32 of Set 6 | uray
# Processing Record 33 of Set 6 | hambantota
# Processing Record 34 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 35 of Set 6 | kalabo
# Processing Record 36 of Set 6 | pasighat
# Processing Record 37 of Set 6 | bababe
# City not found. Skipping...
# Processing Record 38 of Set 6 | shubarkuduk
# Processing Record 39 of Set 6 | kaka
# Processing Record 40 of Set 6 | kibala
# Processing Record 41 of Set 6 | nemuro
# Processing Record 42 of Set 6 | maniitsoq
# Processing Record 43 of Set 6 | inhambane
# Processing Record 44 of Set 6 | alta floresta
# Processing Record 45 of Set 6 | pietarsaari
# Processing Record 46 of Set 6 | rosetta
# Processing Record 47 of Set 6 | colon
# Processing Record 48 of Set 6 | poum
# Processing Record 49 of Set 6 | xiuyan
# Processing Record 50 of Set 6 | soyo
# Processing Record 1 of Set 7 | margate
# Processing Record 2 of Set 7 | strezhevoy
# Processing Record 3 of Set 7 | lorengau
# Processing Record 4 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 7 | pervoye maya
# Processing Record 6 of Set 7 | minab
# Processing Record 7 of Set 7 | tadine
# Processing Record 8 of Set 7 | east london
# Processing Record 9 of Set 7 | lata
# Processing Record 10 of Set 7 | san vicente
# Processing Record 11 of Set 7 | viligili
# City not found. Skipping...
# Processing Record 12 of Set 7 | kavaratti
# Processing Record 13 of Set 7 | sidi ali
# Processing Record 14 of Set 7 | meulaboh
# Processing Record 15 of Set 7 | pevek
# Processing Record 16 of Set 7 | deputatskiy
# Processing Record 17 of Set 7 | verkhnevilyuysk
# Processing Record 18 of Set 7 | kitimat
# Processing Record 19 of Set 7 | clyde river
# Processing Record 20 of Set 7 | honningsvag
# Processing Record 21 of Set 7 | jutai
# Processing Record 22 of Set 7 | moyale
# Processing Record 23 of Set 7 | iquique
# Processing Record 24 of Set 7 | kheralu
# Processing Record 25 of Set 7 | deloraine
# Processing Record 26 of Set 7 | chokurdakh
# Processing Record 27 of Set 7 | san carlos de bariloche
# Processing Record 28 of Set 7 | kruisfontein
# Processing Record 29 of Set 7 | vao
# Processing Record 30 of Set 7 | nome
# Processing Record 31 of Set 7 | solnechnyy
# Processing Record 32 of Set 7 | hundorp
# Processing Record 33 of Set 7 | preobrazheniye
# Processing Record 34 of Set 7 | college
# Processing Record 35 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 7 | lokosovo
# Processing Record 37 of Set 7 | broome
# Processing Record 38 of Set 7 | nanortalik
# Processing Record 39 of Set 7 | horka nad moravou
# Processing Record 40 of Set 7 | stockton-on-tees
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | provideniya
# Processing Record 43 of Set 7 | mount isa
# Processing Record 44 of Set 7 | port lavaca
# Processing Record 45 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 7 | giyani
# Processing Record 47 of Set 7 | san cristobal
# Processing Record 48 of Set 7 | garowe
# Processing Record 49 of Set 7 | kirakira
# Processing Record 50 of Set 7 | saint george
# Processing Record 1 of Set 8 | tarakan
# Processing Record 2 of Set 8 | mattru
# Processing Record 3 of Set 8 | emerald
# Processing Record 4 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 8 | uspenka
# Processing Record 6 of Set 8 | ormara
# Processing Record 7 of Set 8 | ippy
# Processing Record 8 of Set 8 | taiping
# Processing Record 9 of Set 8 | malakwal
# Processing Record 10 of Set 8 | derazhnya
# Processing Record 11 of Set 8 | nsanje
# Processing Record 12 of Set 8 | la uribe
# City not found. Skipping...
# Processing Record 13 of Set 8 | kuminskiy
# Processing Record 14 of Set 8 | mondovi
# Processing Record 15 of Set 8 | altay
# Processing Record 16 of Set 8 | batsfjord
# Processing Record 17 of Set 8 | balikpapan
# Processing Record 18 of Set 8 | airai
# Processing Record 19 of Set 8 | kyabe
# Processing Record 20 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 21 of Set 8 | timra
# Processing Record 22 of Set 8 | qasigiannguit
# Processing Record 23 of Set 8 | amambai
# Processing Record 24 of Set 8 | kang
# Processing Record 25 of Set 8 | cacoal
# Processing Record 26 of Set 8 | bandar-e lengeh
# Processing Record 27 of Set 8 | ruwi
# Processing Record 28 of Set 8 | duncan
# Processing Record 29 of Set 8 | batemans bay
# Processing Record 30 of Set 8 | aklavik
# Processing Record 31 of Set 8 | port-gentil
# Processing Record 32 of Set 8 | tsienyane
# City not found. Skipping...
# Processing Record 33 of Set 8 | khatanga
# Processing Record 34 of Set 8 | terrak
# Processing Record 35 of Set 8 | salinopolis
# Processing Record 36 of Set 8 | koforidua
# Processing Record 37 of Set 8 | tomatlan
# Processing Record 38 of Set 8 | kayunga
# Processing Record 39 of Set 8 | calderitas
# Processing Record 40 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 8 | tiznit
# Processing Record 42 of Set 8 | cayenne
# Processing Record 43 of Set 8 | seoul
# Processing Record 44 of Set 8 | saint-philippe
# Processing Record 45 of Set 8 | kudahuvadhoo
# Processing Record 46 of Set 8 | bridlington
# Processing Record 47 of Set 8 | kargil
# Processing Record 48 of Set 8 | turukhansk
# Processing Record 49 of Set 8 | sofiysk
# City not found. Skipping...
# Processing Record 50 of Set 8 | bereda
# Processing Record 1 of Set 9 | hami
# Processing Record 2 of Set 9 | santa paula
# Processing Record 3 of Set 9 | kishtwar
# Processing Record 4 of Set 9 | cascais
# Processing Record 5 of Set 9 | tambul
# City not found. Skipping...
# Processing Record 6 of Set 9 | chabahar
# Processing Record 7 of Set 9 | puri
# Processing Record 8 of Set 9 | constitucion
# Processing Record 9 of Set 9 | vestmannaeyjar
# Processing Record 10 of Set 9 | trairi
# Processing Record 11 of Set 9 | nyimba
# Processing Record 12 of Set 9 | new glasgow
# Processing Record 13 of Set 9 | pucallpa
# Processing Record 14 of Set 9 | esperance
# Processing Record 15 of Set 9 | komsomolskiy
# Processing Record 16 of Set 9 | nikolayevsk-na-amure
# Processing Record 17 of Set 9 | urdoma
# Processing Record 18 of Set 9 | itoman
# Processing Record 19 of Set 9 | barreirinha
# Processing Record 20 of Set 9 | richards bay
# Processing Record 21 of Set 9 | lashio
# Processing Record 22 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 9 | maningrida
# Processing Record 24 of Set 9 | belmonte
# Processing Record 25 of Set 9 | poronaysk
# Processing Record 26 of Set 9 | benguela
# Processing Record 27 of Set 9 | coahuayana
# Processing Record 28 of Set 9 | apache junction
# Processing Record 29 of Set 9 | kargasok
# Processing Record 30 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 31 of Set 9 | beringovskiy
# Processing Record 32 of Set 9 | marsa matruh
# Processing Record 33 of Set 9 | xinyang
# Processing Record 34 of Set 9 | magalia
# Processing Record 35 of Set 9 | san luis
# Processing Record 36 of Set 9 | matay
# Processing Record 37 of Set 9 | mezen
# Processing Record 38 of Set 9 | sovetskiy
# Processing Record 39 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 9 | mrirt
# City not found. Skipping...
# Processing Record 41 of Set 9 | fengzhen
# Processing Record 42 of Set 9 | atar
# Processing Record 43 of Set 9 | pochutla
# Processing Record 44 of Set 9 | yumen
# Processing Record 45 of Set 9 | kondinskoye
# Processing Record 46 of Set 9 | namibe
# Processing Record 47 of Set 9 | weligama
# Processing Record 48 of Set 9 | axim
# Processing Record 49 of Set 9 | oistins
# Processing Record 50 of Set 9 | mahanoro
# Processing Record 1 of Set 10 | saint-augustin
# Processing Record 2 of Set 10 | copiapo
# Processing Record 3 of Set 10 | tripoli
# Processing Record 4 of Set 10 | varfurile
# Processing Record 5 of Set 10 | ghansor
# Processing Record 6 of Set 10 | ardistan
# City not found. Skipping...
# Processing Record 7 of Set 10 | gaoua
# Processing Record 8 of Set 10 | ihosy
# Processing Record 9 of Set 10 | mehamn
# Processing Record 10 of Set 10 | paratinga
# Processing Record 11 of Set 10 | kalakamati
# Processing Record 12 of Set 10 | portland
# Processing Record 13 of Set 10 | hunza
# City not found. Skipping...
# Processing Record 14 of Set 10 | dzhebariki-khaya
# Processing Record 15 of Set 10 | fort nelson
# Processing Record 16 of Set 10 | vaitape
# Processing Record 17 of Set 10 | edd
# Processing Record 18 of Set 10 | san antonio
# Processing Record 19 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 20 of Set 10 | san miguel
# Processing Record 21 of Set 10 | srednekolymsk
# Processing Record 22 of Set 10 | hamilton
# Processing Record 23 of Set 10 | lago da pedra
# Processing Record 24 of Set 10 | dingle
# Processing Record 25 of Set 10 | irece
# Processing Record 26 of Set 10 | jiuquan
# Processing Record 27 of Set 10 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 10 | nyuksenitsa
# Processing Record 29 of Set 10 | bray
# Processing Record 30 of Set 10 | cozumel
# Processing Record 31 of Set 10 | lavrentiya
# Processing Record 32 of Set 10 | tucuman
# Processing Record 33 of Set 10 | oxford
# Processing Record 34 of Set 10 | mizdah
# Processing Record 35 of Set 10 | anloga
# Processing Record 36 of Set 10 | kenai
# Processing Record 37 of Set 10 | vila velha
# Processing Record 38 of Set 10 | mutsu
# Processing Record 39 of Set 10 | hargeysa
# Processing Record 40 of Set 10 | takoradi
# Processing Record 41 of Set 10 | ilulissat
# Processing Record 42 of Set 10 | yongan
# Processing Record 43 of Set 10 | alice springs
# Processing Record 44 of Set 10 | wajima
# Processing Record 45 of Set 10 | chacabuco
# Processing Record 46 of Set 10 | salym
# Processing Record 47 of Set 10 | sukhobuzimskoye
# Processing Record 48 of Set 10 | sao felix do xingu
# Processing Record 49 of Set 10 | veraval
# Processing Record 50 of Set 10 | bulgan
# Processing Record 1 of Set 11 | fairlie
# Processing Record 2 of Set 11 | nizhniy kuranakh
# Processing Record 3 of Set 11 | darnah
# Processing Record 4 of Set 11 | westport
# Processing Record 5 of Set 11 | hirara
# Processing Record 6 of Set 11 | hammerfest
# Processing Record 7 of Set 11 | namatanai
# Processing Record 8 of Set 11 | limbang
# Processing Record 9 of Set 11 | orlik
# Processing Record 10 of Set 11 | praia da vitoria
# Processing Record 11 of Set 11 | nagato
# Processing Record 12 of Set 11 | acarau
# Processing Record 13 of Set 11 | weinan
# Processing Record 14 of Set 11 | kupang
# Processing Record 15 of Set 11 | tura
# Processing Record 16 of Set 11 | necochea
# Processing Record 17 of Set 11 | la rioja
# Processing Record 18 of Set 11 | celestun
# Processing Record 19 of Set 11 | alofi
# Processing Record 20 of Set 11 | pouembout
# Processing Record 21 of Set 11 | kambove
# Processing Record 22 of Set 11 | jasper
# Processing Record 23 of Set 11 | parasia
# Processing Record 24 of Set 11 | belyy yar
# Processing Record 25 of Set 11 | shawville
# Processing Record 26 of Set 11 | laem sing
# Processing Record 27 of Set 11 | nuqui
# Processing Record 28 of Set 11 | shar
# Processing Record 29 of Set 11 | santa cruz del sur
# Processing Record 30 of Set 11 | saint anthony
# Processing Record 31 of Set 11 | kuybyshevskiy zaton
# Processing Record 32 of Set 11 | nosy varika
# Processing Record 33 of Set 11 | comodoro rivadavia
# Processing Record 34 of Set 11 | tortoli
# Processing Record 35 of Set 11 | egvekinot
# Processing Record 36 of Set 11 | malakal
# Processing Record 37 of Set 11 | baghdad
# Processing Record 38 of Set 11 | sembe
# Processing Record 39 of Set 11 | nanyuki
# Processing Record 40 of Set 11 | nykobing
# City not found. Skipping...
# Processing Record 41 of Set 11 | champerico
# Processing Record 42 of Set 11 | beloha
# Processing Record 43 of Set 11 | bairiki
# Processing Record 44 of Set 11 | barawe
# City not found. Skipping...
# Processing Record 45 of Set 11 | ipilan
# Processing Record 46 of Set 11 | barma
# Processing Record 47 of Set 11 | stavrovo
# Processing Record 48 of Set 11 | kulhudhuffushi
# Processing Record 49 of Set 11 | tutoia
# Processing Record 50 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 1 of Set 12 | piacabucu
# Processing Record 2 of Set 12 | yomitan
# City not found. Skipping...
# Processing Record 3 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 12 | yarmouth
# Processing Record 5 of Set 12 | kevelaer
# Processing Record 6 of Set 12 | rawannawi
# City not found. Skipping...
# Processing Record 7 of Set 12 | guayaramerin
# Processing Record 8 of Set 12 | douglas
# Processing Record 9 of Set 12 | vardo
# Processing Record 10 of Set 12 | padang
# Processing Record 11 of Set 12 | maralal
# Processing Record 12 of Set 12 | astara
# Processing Record 13 of Set 12 | kropotkin
# Processing Record 14 of Set 12 | kholodnyy
# Processing Record 15 of Set 12 | ola
# Processing Record 16 of Set 12 | burgos
# Processing Record 17 of Set 12 | isangel
# Processing Record 18 of Set 12 | rongai
# Processing Record 19 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 12 | cervo
# Processing Record 21 of Set 12 | cockburn town
# Processing Record 22 of Set 12 | asaka
# Processing Record 23 of Set 12 | okhotsk
# Processing Record 24 of Set 12 | palmer
# Processing Record 25 of Set 12 | misratah
# Processing Record 26 of Set 12 | mapiripan
# Processing Record 27 of Set 12 | mabaruma
# Processing Record 28 of Set 12 | dublin
# Processing Record 29 of Set 12 | sorland
# Processing Record 30 of Set 12 | flinders
# Processing Record 31 of Set 12 | hofn
# Processing Record 32 of Set 12 | naze
# Processing Record 33 of Set 12 | zaltan
# Processing Record 34 of Set 12 | kaitong
# Processing Record 35 of Set 12 | omboue
# Processing Record 36 of Set 12 | tilichiki
# Processing Record 37 of Set 12 | agirish
# Processing Record 38 of Set 12 | ekibastuz
# Processing Record 39 of Set 12 | faya
# Processing Record 40 of Set 12 | moron
# Processing Record 41 of Set 12 | abonnema
# Processing Record 42 of Set 12 | medicine hat
# Processing Record 43 of Set 12 | katsuura
# Processing Record 44 of Set 12 | caranavi
# Processing Record 45 of Set 12 | juneau
# Processing Record 46 of Set 12 | colesberg
# Processing Record 47 of Set 12 | mayumba
# Processing Record 48 of Set 12 | hervey bay
# Processing Record 49 of Set 12 | durusu
# Processing Record 50 of Set 12 | halifax
# Processing Record 1 of Set 13 | dinsor
# City not found. Skipping...
# Processing Record 2 of Set 13 | saint-pierre
# Processing Record 3 of Set 13 | kentau
# Processing Record 4 of Set 13 | ternate
# Processing Record 5 of Set 13 | russell
# Processing Record 6 of Set 13 | puerto madryn
# Processing Record 7 of Set 13 | colares
# Processing Record 8 of Set 13 | kibre mengist
# Processing Record 9 of Set 13 | manavgat
# Processing Record 10 of Set 13 | mehran
# Processing Record 11 of Set 13 | puerto baquerizo moreno
# Processing Record 12 of Set 13 | ozgon
# City not found. Skipping...
# Processing Record 13 of Set 13 | lamu
# Processing Record 14 of Set 13 | bhind
# Processing Record 15 of Set 13 | vanimo
# Processing Record 16 of Set 13 | piripiri
# Processing Record 17 of Set 13 | luganville
# Processing Record 18 of Set 13 | paamiut
# Processing Record 19 of Set 13 | taybad
# Processing Record 20 of Set 13 | ponta delgada
# Processing Record 21 of Set 13 | tezu
# Processing Record 22 of Set 13 | igdir
# Processing Record 23 of Set 13 | qaqortoq
# Processing Record 24 of Set 13 | fort-shevchenko
# Processing Record 25 of Set 13 | ekhabi
# Processing Record 26 of Set 13 | birakan
# Processing Record 27 of Set 13 | tual
# Processing Record 28 of Set 13 | whitehorse
# Processing Record 29 of Set 13 | sakakah
# Processing Record 30 of Set 13 | gushikawa
# Processing Record 31 of Set 13 | laguna
# Processing Record 32 of Set 13 | yerbogachen
# Processing Record 33 of Set 13 | blythe
# Processing Record 34 of Set 13 | kamenka
# Processing Record 35 of Set 13 | camacupa
# Processing Record 36 of Set 13 | makakilo city
# Processing Record 37 of Set 13 | sturgis
# Processing Record 38 of Set 13 | antalaha
# Processing Record 39 of Set 13 | conakry
# Processing Record 40 of Set 13 | muros
# Processing Record 41 of Set 13 | scottsbluff
# Processing Record 42 of Set 13 | murray bridge
# Processing Record 43 of Set 13 | hov
# Processing Record 44 of Set 13 | phulabani
# Processing Record 45 of Set 13 | manokwari
# Processing Record 46 of Set 13 | biak
# Processing Record 47 of Set 13 | bonthe
# Processing Record 48 of Set 13 | mtwara
# Processing Record 49 of Set 13 | taungdwingyi
# Processing Record 50 of Set 13 | marsaxlokk
# Processing Record 1 of Set 14 | ucluelet
# Processing Record 2 of Set 14 | badvel
# Processing Record 3 of Set 14 | oyama
# Processing Record 4 of Set 14 | bogorodskoye
# Processing Record 5 of Set 14 | taber
# Processing Record 6 of Set 14 | rio gallegos
# Processing Record 7 of Set 14 | swan hill
# Processing Record 8 of Set 14 | tres arroyos
# Processing Record 9 of Set 14 | mareeba
# Processing Record 10 of Set 14 | aviles
# Processing Record 11 of Set 14 | anajatuba
# Processing Record 12 of Set 14 | mount gambier
# Processing Record 13 of Set 14 | pastavy
# Processing Record 14 of Set 14 | port hardy
# Processing Record 15 of Set 14 | lompoc
# Processing Record 16 of Set 14 | paddaya
# Processing Record 17 of Set 14 | alta gracia
# Processing Record 18 of Set 14 | nanchong
# Processing Record 19 of Set 14 | yaan
# Processing Record 20 of Set 14 | namanga
# Processing Record 21 of Set 14 | panaba
# Processing Record 22 of Set 14 | karpathos
# Processing Record 23 of Set 14 | ugoofaaru
# Processing Record 24 of Set 14 | terrace
# Processing Record 25 of Set 14 | ulaanbaatar
# Processing Record 26 of Set 14 | morgan city
# Processing Record 27 of Set 14 | san felipe
# Processing Record 28 of Set 14 | mudgee
# Processing Record 29 of Set 14 | nguiu
# City not found. Skipping...
# Processing Record 30 of Set 14 | cedar city
# Processing Record 31 of Set 14 | aswan
# Processing Record 32 of Set 14 | yarensk
# Processing Record 33 of Set 14 | yar-sale
# Processing Record 34 of Set 14 | san policarpo
# Processing Record 35 of Set 14 | corrales
# Processing Record 36 of Set 14 | kuntaur
# Processing Record 37 of Set 14 | goure
# Processing Record 38 of Set 14 | nouakchott
# Processing Record 39 of Set 14 | plettenberg bay
# Processing Record 40 of Set 14 | nexo
# Processing Record 41 of Set 14 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 14 | kashi
# Processing Record 43 of Set 14 | nioro
# Processing Record 44 of Set 14 | almaznyy
# Processing Record 45 of Set 14 | santa cruz cabralia
# Processing Record 46 of Set 14 | buenos aires
# Processing Record 47 of Set 14 | yarada
# Processing Record 48 of Set 14 | nelson bay
# Processing Record 49 of Set 14 | shagonar
# Processing Record 50 of Set 14 | butembo
# Processing Record 1 of Set 15 | estefania
# Processing Record 2 of Set 15 | zyryanskoye
# Processing Record 3 of Set 15 | korhogo
# Processing Record 4 of Set 15 | khani
# Processing Record 5 of Set 15 | harper
# Processing Record 6 of Set 15 | kiama
# Processing Record 7 of Set 15 | worpswede
# Processing Record 8 of Set 15 | dvinskoy
# Processing Record 9 of Set 15 | eydhafushi
# Processing Record 10 of Set 15 | taoudenni
# Processing Record 11 of Set 15 | okandja
# City not found. Skipping...
# Processing Record 12 of Set 15 | banjar
# Processing Record 13 of Set 15 | svarstad
# Processing Record 14 of Set 15 | san quintin
# Processing Record 15 of Set 15 | honiara
# Processing Record 16 of Set 15 | alakurtti
# Processing Record 17 of Set 15 | vemalwada
# Processing Record 18 of Set 15 | kyaikto
# Processing Record 19 of Set 15 | mitsamiouli
# Processing Record 20 of Set 15 | camacha
# Processing Record 21 of Set 15 | danjiangkou
# Processing Record 22 of Set 15 | sinnamary
# Processing Record 23 of Set 15 | hameenlinna
# Processing Record 24 of Set 15 | charters towers
# Processing Record 25 of Set 15 | boyolangu
# Processing Record 26 of Set 15 | sanary-sur-mer
# Processing Record 27 of Set 15 | bulolo
# Processing Record 28 of Set 15 | laviana
# Processing Record 29 of Set 15 | spornoye
# Processing Record 30 of Set 15 | pskov
# Processing Record 31 of Set 15 | dolny kubin
# Processing Record 32 of Set 15 | seydi
# Processing Record 33 of Set 15 | muscatine
# Processing Record 34 of Set 15 | carutapera
# Processing Record 35 of Set 15 | jumla
# Processing Record 36 of Set 15 | maragheh
# Processing Record 37 of Set 15 | ust-tsilma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart -42.8794  147.3294     67.86        75          75
# 1  Ponta Do Sol  32.6667  -17.1000     60.71        61          88
# 2   Port Alfred -33.5906   26.8910     66.18        89          50
# 3       Jurmala  56.9680   23.7704     28.42        93           0
# 4        Rincon  32.2960  -81.2354     65.86        42           0
# 5   Terrace Bay  48.7834  -87.1000     31.42        98          88
# 6         Sitka  57.0531 -135.3300     42.69        65          75
# 7        Uribia  11.7139  -72.2660     79.92        74          85
# 8        Baykit  61.6700   96.3700     17.65        87          28
# 9         Tiksi  71.6872  128.8694      6.66        92         100
#
#    Wind Speed Current Description Country                 Date
# 0        8.05       broken clouds      AU  2022-04-04 01:42:40
# 1       13.53     overcast clouds      PT  2022-04-04 01:46:35
# 2        1.01    scattered clouds      ZA  2022-04-04 01:45:23
# 3        8.05           clear sky      LV  2022-04-04 01:46:37
# 4        0.00           clear sky      US  2022-04-04 01:46:38
# 5        6.17     overcast clouds      CA  2022-04-04 01:46:39
# 6        8.05       broken clouds      US  2022-04-04 01:45:15
# 7       13.71     overcast clouds      CO  2022-04-04 01:46:41
# 8        2.04    scattered clouds      RU  2022-04-04 01:46:42
# 9        8.81     overcast clouds      RU  2022-04-04 01:46:43

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Hobart      AU -42.8794  147.3294     67.86        75          75
# 1  Ponta Do Sol      PT  32.6667  -17.1000     60.71        61          88
# 2   Port Alfred      ZA -33.5906   26.8910     66.18        89          50
# 3       Jurmala      LV  56.9680   23.7704     28.42        93           0
# 4        Rincon      US  32.2960  -81.2354     65.86        42           0
# 5   Terrace Bay      CA  48.7834  -87.1000     31.42        98          88
# 6         Sitka      US  57.0531 -135.3300     42.69        65          75
# 7        Uribia      CO  11.7139  -72.2660     79.92        74          85
# 8        Baykit      RU  61.6700   96.3700     17.65        87          28
# 9         Tiksi      RU  71.6872  128.8694      6.66        92         100
#
#    Wind Speed Current Description
# 0        8.05       broken clouds
# 1       13.53     overcast clouds
# 2        1.01    scattered clouds
# 3        8.05           clear sky
# 4        0.00           clear sky
# 5        6.17     overcast clouds
# 6        8.05       broken clouds
# 7       13.71     overcast clouds
# 8        2.04    scattered clouds
# 9        8.81     overcast clouds

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label="City_ID")
